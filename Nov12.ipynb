# %%
l=['b','y','e']
l[1]='e'
l=l+['e']
l.append('y')
l.pop(0)
print(l)
# Out:
# ['e', 'e', 'e', 'y']

# %%
list=[4,3,56,6,3,9]
list.sort()
print(list)
# Out:
# [3, 3, 4, 6, 9, 56]

# %%
list=[4,5,6,99,43,65,
