# %%
d={1:"one",2:"two",3:"three"}
print(d[1])
# Out:
# one

# %%
p={"raj":1,"ram":2,"shyam":3}
print(p)
p["raj"]=4
print(p)
# Out:
# {'raj': 1, 'ram': 2, 'shyam': 3}
# {'raj': 4, 'ram': 2, 'shyam': 3}

# %%
emp_nums={}
while True:
    name= input("Enter name:")
    number = input("Enter number:")
    emp_nums[name]=number
    print(emp_nums)
